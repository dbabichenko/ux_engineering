# %% [markdown]
# ## Sentiment Analysis of HeritageRoots VR Think-Aloud
#
# #### Transcripts with NLTK (VADER)
#
# 1. Load a JSON dataset
# 2. Extract Participant lines (ignoring Interviewer lines)
# 3. Use NLTK VADER to score sentiment per utterance
# 4. Aggregate sentiment per participant and saves CSVs

# %%
import json
import os
from pathlib import Path
from typing import List, Dict

# Data wrangling
import pandas as pd

# NLTK VADER sentiment
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
# ---------- Config ----------
DATA_PATH = Path("data/heritageroots_ux_transcripts.json")  
OUT_DIR = Path("data/sentiment_outputs")
OUT_DIR.mkdir(exist_ok=True)

# %%
# ---------- Ensure VADER is available ----------
# If your environment doesn't have the lexicon, uncomment the download line.
# (In some teaching environments, internet is blocked; if so, pre-install before class.)
try:
    _ = SentimentIntensityAnalyzer()
except:
    nltk.download("vader_lexicon")

# Create analyzer (now that we (should) have the lexicon)
sia = SentimentIntensityAnalyzer()

# %%
# ---------- Load JSON ----------
if not DATA_PATH.exists():
    raise FileNotFoundError(f"Could not find {DATA_PATH.resolve()}. "
                            "Place the JSON in this folder or update DATA_PATH.")

with open(DATA_PATH, "r", encoding="utf-8") as f:
    data = json.load(f)

participants = data.get("participants", [])
print(f"Loaded {len(participants)} participants.")
# Out:
# Loaded 20 participants.

# %%
participants
# Out:
# [{'id': 'P01',
#   'bio': '24-year-old Computer Science student named Alex, female, highly familiar with VR and technology.',
#   'transcript': [{'time': '[00:00:14]',
#     'speaker': 'Interviewer',
#     'text': 'You are now in the HeritageRoots virtual lobby. What do you notice first?'},
#    {'time': '[00:00:48]',
#     'speaker': 'Participant',
#     'text': 'The lighting and spatial sound immediately make it feel immersive. I noticed the floating panels, but wasn’t sure which gesture activates them.'},
#    {'time': '[00:00:59]',
#     'speaker': 'Interviewer',
#     'text': 'Try navigating to a new scene using the teleport tool.'},
#    {'time': '[00:01:20]',
#     'speaker': 'Participant',
#     'text': 'Teleportation is smooth, but I’d like a quick preview of where I’ll land. The fade helps, but maybe a clearer arrow would help directionally.'},
#    {'time': '[00:01:39]',
#     'speaker': 'Interviewer',
#     'text': 'How do the menus and icons feel to interact with?'},
#    {'time': '[00:01:54]',
#     'speaker': 'Participant',
#     'text': 'The icons are intuitive but slightly small. I prefer when menus curve around my view instead of staying flat in front of me.'},
#    {'time': '[00:02:04]',
#     'speaker': 'Interviewer',
#     'text': 'Can you describe how object interaction feels?'},
#    {'time': '[00:02:16]',
#     'speaker': 'Participant',
#     'text': 'Picking up artifacts feels satisfying. However, I expected some haptic feedback when I grabbed something, maybe a small vibration.'},
#    {'time': '[00:02:50]',
#     'speaker': 'Interviewer',
#     'text': 'Any technical or comfort issues?'},
#    {'time': '[00:03:08]',
#     'speaker': 'Participant',
#     'text': 'No lag, though the ambient sound loop is a little short—I noticed repetition after a few minutes.'},
#    {'time': '[00:03:41]',
#     'speaker': 'Interviewer',
#     'text': 'How would you rate the overall ease of use?'},
#    {'time': '[00:03:54]',
#     'speaker': 'Participant',
#     'text': 'Pretty intuitive overall. I’d just tweak interaction cues and maybe add a tutorial overlay at first launch.'}]},
#  {'id': 'P02',
#   'bio': '22-year-old Anthropology student named Jamie, male, highly familiar with VR and technology.',
#   'transcript': [{'time': '[00:00:07]',
#     'speaker': 'Interviewer',
#     'text': 'You are now in the HeritageRoots virtual lobby. What do you notice first?'},
#    {'time': '[00:00:37]',
#     'speaker': 'Participant',
#     'text': 'The lighting and spatial sound immediately make it feel immersive. I noticed the floating panels, but wasn’t sure which gesture activates them.'},
#    {'time': '[00:00:55]',
#     'speaker': 'Interviewer',
#     'text': 'Try navigating to a new scene using the teleport tool.'},
#    {'time': '[00:01:24]',
#     'speaker': 'Participant',
#     'text': 'Teleportation is smooth, but I’d like a quick preview of where I’ll land. The fade helps, but maybe a clearer arrow would help directionally.'},
#    {'time': '[00:01:58]',
#     'speaker': 'Interviewer',
#     'text': 'How do the menus and icons feel to interact with?'},
#    {'time': '[00:02:04]',
#     'speaker': 'Participant',
#     'text': 'The icons are intuitive but slightly small. I prefer when menus curve around my view instead of staying flat in front of me.'},
#    {'time': '[00:02:13]',
#     'speaker': 'Interviewer',
#     'text': 'Can you describe how object interaction feels?'},
#    {'time': '[00:02:33]',
#     'speaker': 'Participant',
#     'text': 'Picking up artifacts feels satisfying. However, I expected some haptic feedback when I grabbed something, maybe a small vibration.'},
#    {'time': '[00:02:38]',
#     'speaker': 'Interviewer',
#     'text': 'Any technical or comfort issues?'},
#    {'time': '[00:02:55]',
#     'speaker': 'Participant',
#     'text': 'No lag, though the ambient sound loop is a little short—I noticed repetition after a few minutes.'},
#    {'time': '[00:03:04]',
#     'speaker': 'Interviewer',
#     'text': 'How would you rate the overall ease of use?'},
#    {'time': '[00:03:15]',
#     'speaker': 'Participant',
#     'text': 'Pretty intuitive overall. I’d just tweak interaction cues and maybe add a tutorial overlay at first launch.'}]},
#  {'id': 'P03',
#   'bio': '21-year-old Engineering student named Taylor, male, highly familiar with VR and technology.',
#   'transcript': [{'time': '[00:00:15]',
#     'speaker': 'Interviewer',
#     'text': 'You are now in the HeritageRoots virtual lobby. What do you notice first?'},
#    {'time': '[00:00:40]',
#     'speaker': 'Participant',
#     'text': 'The lighting and spatial sound immediately make it feel immersive. I noticed the floating panels, but wasn’t sure which gesture activates them.'},
#    {'time': '[00:00:49]',
#     'speaker': 'Interviewer',
#     'text': 'Try navigating to a new scene using the teleport tool.'},
#    {'time': '[00:01:21]',
#     'speaker': 'Participant',
#     'text': 'Teleportation is smooth, but I’d like a quick preview of where I’ll land. The fade helps, but maybe a clearer arrow would help directionally.'},
#    {'time': '[00:01:45]',
#     'speaker': 'Interviewer',
#     'text': 'How do the menus and icons feel to interact with?'},
#    {'time': '[00:02:03]',
#     'speaker': 'Participant',
#     'text': 'The icons are intuitive but slightly small. I prefer when menus curve around my view instead of staying flat in front of me.'},
#    {'time': '[00:02:19]',
#     'speaker': 'Interviewer',
#     'text': 'Can you describe how object interaction feels?'},
#    {'time': '[00:02:35]',
#     'speaker': 'Participant',
#     'text': 'Picking up artifacts feels satisfying. However, I expected some haptic feedback when I grabbed something, maybe a small vibration.'},
#    {'time': '[00:02:48]',
#     'speaker': 'Interviewer',
#     'text': 'Any technical or comfort issues?'},
#    {'time': '[00:03:12]',
#     'speaker': 'Participant',
#     'text': 'No lag, though the ambient sound loop is a little short—I noticed repetition after a few minutes.'},
#    {'time': '[00:03:31]',
#     'speaker': 'Interviewer',
#     'text': 'How would you rate the overall ease of use?'},
#    {'time': '[00:03:55]',
#     'speaker': 'Participant',
#     'text': 'Pretty intuitive overall. I’d just tweak interaction cues and maybe add a tutorial overlay at first launch.'}]},
#  {'id': 'P04',
#   'bio': '24-year-old Design student named Jordan, female, highly familiar with VR and technology.',
#   'transcript': [{'time': '[00:00:23]',
#     'speaker': 'Interviewer',
#     'text': 'You are now in the HeritageRoots virtual lobby. What do you notice first?'},
#    {'time': '[00:00:51]',
#     'speaker': 'Participant',
#     'text': 'The lighting and spatial sound immediately make it feel immersive. I noticed the floating panels, but wasn’t sure which gesture activates them.'},
#    {'time': '[00:01:26]',
#     'speaker': 'Interviewer',
#     'text': 'Try navigating to a new scene using the teleport tool.'},
#    {'time': '[00:01:36]',
#     'speaker': 'Participant',
#     'text': 'Teleportation is smooth, but I’d like a quick preview of where I’ll land. The fade helps, but maybe a clearer arrow would help directionally.'},
#    {'time': '[00:02:08]',
#     'speaker': 'Interviewer',
#     'text': 'How do the menus and icons feel to interact with?'},
#    {'time': '[00:02:31]',
#     'speaker': 'Participant',
#     'text': 'The icons are intuitive but slightly small. I prefer when menus curve around my view instead of staying flat in front of me.'},
#    {'time': '[00:02:59]',
#     'speaker': 'Interviewer',
#     'text': 'Can you describe how object interaction feels?'},
#    {'time': '[00:03:12]',
#     'speaker': 'Participant',
#     'text': 'Picking up artifacts feels satisfying. However, I expected some haptic feedback when I grabbed something, maybe a small vibration.'},
#    {'time': '[00:03:41]',
#     'speaker': 'Interviewer',
#     'text': 'Any technical or comfort issues?'},
#    {'time': '[00:04:12]',
#     'speaker': 'Participant',
#     'text': 'No lag, though the ambient sound loop is a little short—I noticed repetition after a few minutes.'},
#    {'time': '[00:04:46]',
#     'speaker': 'Interviewer',
#     'text': 'How would you rate the overall ease of use?'},
#    {'time': '[00:05:14]',
#     'speaker': 'Participant',
#     'text': 'Pretty intuitive overall. I’d just tweak interaction cues and maybe add a tutorial overlay at first launch.'}]},
#  {'id': 'P05',
#   'bio': '28-year-old Information Science student named Casey, female, highly familiar with VR and technology.',
#   'transcript': [{'time': '[00:00:24]',
#     'speaker': 'Interviewer',
#     'text': 'You are now in the HeritageRoots virtual lobby. What do you notice first?'},
#    {'time': '[00:00:45]',
#     'speaker': 'Participant',
#     'text': 'The lighting and spatial sound immediately make it feel immersive. I noticed the floating panels, but wasn’t sure which gesture activates them.'},
#    {'time': '[00:01:15]',
#     'speaker': 'Interviewer',
#     'text': 'Try navigating to a new scene using the teleport tool.'},
#    {'time': '[00:01:22]',
#     'speaker': 'Participant',
#     'text': 'Teleportation is smooth, but I’d like a quick preview of where I’ll land. The fade helps, but maybe a clearer arrow would help directionally.'},
#    {'time': '[00:01:37]',
#     'speaker': 'Interviewer',
#     'text': 'How do the menus and icons feel to interact with?'},
#    {'time': '[00:01:54]',
#     'speaker': 'Participant',
#     'text': 'The icons are intuitive but slightly small. I prefer when menus curve around my view instead of staying flat in front of me.'},
#    {'time': '[00:02:05]',
#     'speaker': 'Interviewer',
#     'text': 'Can you describe how object interaction feels?'},
#    {'time': '[00:02:28]',
#     'speaker': 'Participant',
#     'text': 'Picking up artifacts feels satisfying. However, I expected some haptic feedback when I grabbed something, maybe a small vibration.'},
#    {'time': '[00:02:36]',
#     'speaker': 'Interviewer',
#     'text': 'Any technical or comfort issues?'},
#    {'time': '[00:02:42]',
#     'speaker': 'Participant',
#     'text': 'No lag, though the ambient sound loop is a little short—I noticed repetition after a few minutes.'},
#    {'time': '[00:02:49]',
#     'speaker': 'Interviewer',
#     'text': 'How would you rate the overall ease of use?'},
#    {'time': '[00:03:06]',
#     'speaker': 'Participant',
#     'text': 'Pretty intuitive overall. I’d just tweak interaction cues and maybe add a tutorial overlay at first launch.'}]},
#  {'id': 'P06',
#   'bio': '20-year-old Linguistics student named Riley, male, highly familiar with VR and technology.',
#   'transcript': [{'time': '[00:00:17]',
#     'speaker': 'Interviewer',
#     'text': 'You are now in the HeritageRoots virtual lobby. What do you notice first?'},
#    {'time': '[00:00:34]',
#     'speaker': 'Participant',
#     'text': 'The lighting and spatial sound immediately make it feel immersive. I noticed the floating panels, but wasn’t sure which gesture activates them.'},
#    {'time': '[00:00:42]',
#     'speaker': 'Interviewer',
#     'text': 'Try navigating to a new scene using the teleport tool.'},
#    {'time': '[00:01:09]',
#     'speaker': 'Participant',
#     'text': 'Teleportation is smooth, but I’d like a quick preview of where I’ll land. The fade helps, but maybe a clearer arrow would help directionally.'},
#    {'time': '[00:01:33]',
#     'speaker': 'Interviewer',
#     'text': 'How do the menus and icons feel to interact with?'},
#    {'time': '[00:01:57]',
#     'speaker': 'Participant',
#     'text': 'The icons are intuitive but slightly small. I prefer when menus curve around my view instead of staying flat in front of me.'},
#    {'time': '[00:02:19]',
#     'speaker': 'Interviewer',
#     'text': 'Can you describe how object interaction feels?'},
#    {'time': '[00:02:30]',
#     'speaker': 'Participant',
#     'text': 'Picking up artifacts feels satisfying. However, I expected some haptic feedback when I grabbed something, maybe a small vibration.'},
#    {'time': '[00:02:42]',
#     'speaker': 'Interviewer',
#     'text': 'Any technical or comfort issues?'},
#    {'time': '[00:03:12]',
#     'speaker': 'Participant',
#     'text': 'No lag, though the ambient sound loop is a little short—I noticed repetition after a few minutes.'},
#    {'time': '[00:03:35]',
#     'speaker': 'Interviewer',
#     'text': 'How would you rate the overall ease of use?'},
#    {'time': '[00:03:47]',
#     'speaker': 'Participant',
#     'text': 'Pretty intuitive overall. I’d just tweak interaction cues and maybe add a tutorial overlay at first launch.'}]},
#  {'id': 'P07',
#   'bio': '27-year-old History student named Morgan, nonbinary, highly familiar with VR and technology.',
#   'transcript': [{'time': '[00:00:27]',
#     'speaker': 'Interviewer',
#     'text': 'You are now in the HeritageRoots virtual lobby. What do you notice first?'},
#    {'time': '[00:00:35]',
#     'speaker': 'Participant',
#     'text': 'The lighting and spatial sound immediately make it feel immersive. I noticed the floating panels, but wasn’t sure which gesture activates them.'},
#    {'time': '[00:00:41]',
#     'speaker': 'Interviewer',
#     'text': 'Try navigating to a new scene using the teleport tool.'},
#    {'time': '[00:00:46]',
#     'speaker': 'Participant',
#     'text': 'Teleportation is smooth, but I’d like a quick preview of where I’ll land. The fade helps, but maybe a clearer arrow would help directionally.'},
#    {'time': '[00:01:07]',
#     'speaker': 'Interviewer',
#     'text': 'How do the menus and icons feel to interact with?'},
#    {'time': '[00:01:21]',
#     'speaker': 'Participant',
#     'text': 'The icons are intuitive but slightly small. I prefer when menus curve around my view instead of staying flat in front of me.'},
#    {'time': '[00:01:44]',
#     'speaker': 'Interviewer',
#     'text': 'Can you describe how object interaction feels?'},
#    {'time': '[00:02:09]',
#     'speaker': 'Participant',
#     'text': 'Picking up artifacts feels satisfying. However, I expected some haptic feedback when I grabbed something, maybe a small vibration.'},
#    {'time': '[00:02:33]',
#     'speaker': 'Interviewer',
#     'text': 'Any technical or comfort issues?'},
#    {'time': '[00:02:52]',
#     'speaker': 'Participant',
#     'text': 'No lag, though the ambient sound loop is a little short—I noticed repetition after a few minutes.'},
#    {'time': '[00:03:20]',
#     'speaker': 'Interviewer',
#     'text': 'How would you rate the overall ease of use?'},
#    {'time': '[00:03:47]',
#     'speaker': 'Participant',
#     'text': 'Pretty intuitive overall. I’d just tweak interaction cues and maybe add a tutorial overlay at first launch.'}]},
#  {'id': 'P08',
#   'bio': '25-year-old Media Studies student named Cameron, male, highly familiar with VR and technology.',
#   'transcript': [{'time': '[00:00:22]',
#     'speaker': 'Interviewer',
#     'text': 'You are now in the HeritageRoots virtual lobby. What do you notice first?'},
#    {'time': '[00:00:37]',
#     'speaker': 'Participant',
#     'text': 'The lighting and spatial sound immediately make it feel immersive. I noticed the floating panels, but wasn’t sure which gesture activates them.'},
#    {'time': '[00:00:59]',
#     'speaker': 'Interviewer',
#     'text': 'Try navigating to a new scene using the teleport tool.'},
#    {'time': '[00:01:20]',
#     'speaker': 'Participant',
#     'text': 'Teleportation is smooth, but I’d like a quick preview of where I’ll land. The fade helps, but maybe a clearer arrow would help directionally.'},
#    {'time': '[00:01:48]',
#     'speaker': 'Interviewer',
#     'text': 'How do the menus and icons feel to interact with?'},
#    {'time': '[00:01:59]',
#     'speaker': 'Participant',
#     'text': 'The icons are intuitive but slightly small. I prefer when menus curve around my view instead of staying flat in front of me.'},
#    {'time': '[00:02:04]',
#     'speaker': 'Interviewer',
#     'text': 'Can you describe how object interaction feels?'},
#    {'time': '[00:02:20]',
#     'speaker': 'Participant',
#     'text': 'Picking up artifacts feels satisfying. However, I expected some haptic feedback when I grabbed something, maybe a small vibration.'},
#    {'time': '[00:02:35]',
#     'speaker': 'Interviewer',
#     'text': 'Any technical or comfort issues?'},
#    {'time': '[00:03:05]',
#     'speaker': 'Participant',
#     'text': 'No lag, though the ambient sound loop is a little short—I noticed repetition after a few minutes.'},
#    {'time': '[00:03:20]',
#     'speaker': 'Interviewer',
#     'text': 'How would you rate the overall ease of use?'},
#    {'time': '[00:03:54]',
#     'speaker': 'Participant',
#     'text': 'Pretty intuitive overall. I’d just tweak interaction cues and maybe add a tutorial overlay at first launch.'}]},
#  {'id': 'P09',
#   'bio': '30-year-old Architecture student named Avery, nonbinary, highly familiar with VR and technology.',
#   'transcript': [{'time': '[00:00:11]',
#     'speaker': 'Interviewer',
#     'text': 'You are now in the HeritageRoots virtual lobby. What do you notice first?'},
#    {'time': '[00:00:20]',
#     'speaker': 'Participant',
#     'text': 'The lighting and spatial sound immediately make it feel immersive. I noticed the floating panels, but wasn’t sure which gesture activates them.'},
#    {'time': '[00:00:30]',
#     'speaker': 'Interviewer',
#     'text': 'Try navigating to a new scene using the teleport tool.'},
#    {'time': '[00:00:49]',
#     'speaker': 'Participant',
#     'text': 'Teleportation is smooth, but I’d like a quick preview of where I’ll land. The fade helps, but maybe a clearer arrow would help directionally.'},
#    {'time': '[00:01:01]',
#     'speaker': 'Interviewer',
#     'text': 'How do the menus and icons feel to interact with?'},
#    {'time': '[00:01:30]',
#     'speaker': 'Participant',
#     'text': 'The icons are intuitive but slightly small. I prefer when menus curve around my view instead of staying flat in front of me.'},
#    {'time': '[00:01:38]',
#     'speaker': 'Interviewer',
#     'text': 'Can you describe how object interaction feels?'},
#    {'time': '[00:02:04]',
#     'speaker': 'Participant',
#     'text': 'Picking up artifacts feels satisfying. However, I expected some haptic feedback when I grabbed something, maybe a small vibration.'},
#    {'time': '[00:02:09]',
#     'speaker': 'Interviewer',
#     'text': 'Any technical or comfort issues?'},
#    {'time': '[00:02:33]',
#     'speaker': 'Participant',
#     'text': 'No lag, though the ambient sound loop is a little short—I noticed repetition after a few minutes.'},
#    {'time': '[00:02:59]',
#     'speaker': 'Interviewer',
#     'text': 'How would you rate the overall ease of use?'},
#    {'time': '[00:03:27]',
#     'speaker': 'Participant',
#     'text': 'Pretty intuitive overall. I’d just tweak interaction cues and maybe add a tutorial overlay at first launch.'}]},
#  {'id': 'P10',
#   'bio': '27-year-old Psychology student named Skyler, female, highly familiar with VR and technology.',
#   'transcript': [{'time': '[00:00:09]',
#     'speaker': 'Interviewer',
#     'text': 'You are now in the HeritageRoots virtual lobby. What do you notice first?'},
#    {'time': '[00:00:14]',
#     'speaker': 'Participant',
#     'text': 'The lighting and spatial sound immediately make it feel immersive. I noticed the floating panels, but wasn’t sure which gesture activates them.'},
#    {'time': '[00:00:39]',
#     'speaker': 'Interviewer',
#     'text': 'Try navigating to a new scene using the teleport tool.'},
#    {'time': '[00:01:08]',
#     'speaker': 'Participant',
#     'text': 'Teleportation is smooth, but I’d like a quick preview of where I’ll land. The fade helps, but maybe a clearer arrow would help directionally.'},
#    {'time': '[00:01:33]',
#     'speaker': 'Interviewer',
#     'text': 'How do the menus and icons feel to interact with?'},
#    {'time': '[00:02:08]',
#     'speaker': 'Participant',
#     'text': 'The icons are intuitive but slightly small. I prefer when menus curve around my view instead of staying flat in front of me.'},
#    {'time': '[00:02:26]',
#     'speaker': 'Interviewer',
#     'text': 'Can you describe how object interaction feels?'},
#    {'time': '[00:02:43]',
#     'speaker': 'Participant',
#     'text': 'Picking up artifacts feels satisfying. However, I expected some haptic feedback when I grabbed something, maybe a small vibration.'},
#    {'time': '[00:03:15]',
#     'speaker': 'Interviewer',
#     'text': 'Any technical or comfort issues?'},
#    {'time': '[00:03:37]',
#     'speaker': 'Participant',
#     'text': 'No lag, though the ambient sound loop is a little short—I noticed repetition after a few minutes.'},
#    {'time': '[00:03:43]',
#     'speaker': 'Interviewer',
#     'text': 'How would you rate the overall ease of use?'},
#    {'time': '[00:04:08]',
#     'speaker': 'Participant',
#     'text': 'Pretty intuitive overall. I’d just tweak interaction cues and maybe add a tutorial overlay at first launch.'}]},
#  {'id': 'P11',
#   'bio': '25-year-old Sociology student named Rowan, male, highly familiar with VR and technology.',
#   'transcript': [{'time': '[00:00:30]',
#     'speaker': 'Interviewer',
#     'text': 'You are now in the HeritageRoots virtual lobby. What do you notice first?'},
#    {'time': '[00:00:37]',
#     'speaker': 'Participant',
#     'text': 'The lighting and spatial sound immediately make it feel immersive. I noticed the floating panels, but wasn’t sure which gesture activates them.'},
#    {'time': '[00:00:42]',
#     'speaker': 'Interviewer',
#     'text': 'Try navigating to a new scene using the teleport tool.'},
#    {'time': '[00:01:08]',
#     'speaker': 'Participant',
#     'text': 'Teleportation is smooth, but I’d like a quick preview of where I’ll land. The fade helps, but maybe a clearer arrow would help directionally.'},
#    {'time': '[00:01:18]',
#     'speaker': 'Interviewer',
#     'text': 'How do the menus and icons feel to interact with?'},
#    {'time': '[00:01:41]',
#     'speaker': 'Participant',
#     'text': 'The icons are intuitive but slightly small. I prefer when menus curve around my view instead of staying flat in front of me.'},
#    {'time': '[00:01:58]',
#     'speaker': 'Interviewer',
#     'text': 'Can you describe how object interaction feels?'},
#    {'time': '[00:02:14]',
#     'speaker': 'Participant',
#     'text': 'Picking up artifacts feels satisfying. However, I expected some haptic feedback when I grabbed something, maybe a small vibration.'},
#    {'time': '[00:02:48]',
#     'speaker': 'Interviewer',
#     'text': 'Any technical or comfort issues?'},
#    {'time': '[00:03:04]',
#     'speaker': 'Participant',
#     'text': 'No lag, though the ambient sound loop is a little short—I noticed repetition after a few minutes.'},
#    {'time': '[00:03:33]',
#     'speaker': 'Interviewer',
#     'text': 'How would you rate the overall ease of use?'},
#    {'time': '[00:04:04]',
#     'speaker': 'Participant',
#     'text': 'Pretty intuitive overall. I’d just tweak interaction cues and maybe add a tutorial overlay at first launch.'}]},
#  {'id': 'P12',
#   'bio': '26-year-old Digital Humanities student named Quinn, male, highly familiar with VR and technology.',
#   'transcript': [{'time': '[00:00:20]',
#     'speaker': 'Interviewer',
#     'text': 'You are now in the HeritageRoots virtual lobby. What do you notice first?'},
#    {'time': '[00:00:36]',
#     'speaker': 'Participant',
#     'text': 'The lighting and spatial sound immediately make it feel immersive. I noticed the floating panels, but wasn’t sure which gesture activates them.'},
#    {'time': '[00:01:09]',
#     'speaker': 'Interviewer',
#     'text': 'Try navigating to a new scene using the teleport tool.'},
#    {'time': '[00:01:40]',
#     'speaker': 'Participant',
#     'text': 'Teleportation is smooth, but I’d like a quick preview of where I’ll land. The fade helps, but maybe a clearer arrow would help directionally.'},
#    {'time': '[00:02:10]',
#     'speaker': 'Interviewer',
#     'text': 'How do the menus and icons feel to interact with?'},
#    {'time': '[00:02:39]',
#     'speaker': 'Participant',
#     'text': 'The icons are intuitive but slightly small. I prefer when menus curve around my view instead of staying flat in front of me.'},
#    {'time': '[00:02:46]',
#     'speaker': 'Interviewer',
#     'text': 'Can you describe how object interaction feels?'},
#    {'time': '[00:03:19]',
#     'speaker': 'Participant',
#     'text': 'Picking up artifacts feels satisfying. However, I expected some haptic feedback when I grabbed something, maybe a small vibration.'},
#    {'time': '[00:03:37]',
#     'speaker': 'Interviewer',
#     'text': 'Any technical or comfort issues?'},
#    {'time': '[00:03:58]',
#     'speaker': 'Participant',
#     'text': 'No lag, though the ambient sound loop is a little short—I noticed repetition after a few minutes.'},
#    {'time': '[00:04:30]',
#     'speaker': 'Interviewer',
#     'text': 'How would you rate the overall ease of use?'},
#    {'time': '[00:04:47]',
#     'speaker': 'Participant',
#     'text': 'Pretty intuitive overall. I’d just tweak interaction cues and maybe add a tutorial overlay at first launch.'}]},
#  {'id': 'P13',
#   'bio': '21-year-old Education student named Reese, nonbinary, highly familiar with VR and technology.',
#   'transcript': [{'time': '[00:00:10]',
#     'speaker': 'Interviewer',
#     'text': 'You are now in the HeritageRoots virtual lobby. What do you notice first?'},
#    {'time': '[00:00:30]',
#     'speaker': 'Participant',
#     'text': 'The lighting and spatial sound immediately make it feel immersive. I noticed the floating panels, but wasn’t sure which gesture activates them.'},
#    {'time': '[00:00:55]',
#     'speaker': 'Interviewer',
#     'text': 'Try navigating to a new scene using the teleport tool.'},
#    {'time': '[00:01:04]',
#     'speaker': 'Participant',
#     'text': 'Teleportation is smooth, but I’d like a quick preview of where I’ll land. The fade helps, but maybe a clearer arrow would help directionally.'},
#    {'time': '[00:01:13]',
#     'speaker': 'Interviewer',
#     'text': 'How do the menus and icons feel to interact with?'},
#    {'time': '[00:01:45]',
#     'speaker': 'Participant',
#     'text': 'The icons are intuitive but slightly small. I prefer when menus curve around my view instead of staying flat in front of me.'},
#    {'time': '[00:02:19]',
#     'speaker': 'Interviewer',
#     'text': 'Can you describe how object interaction feels?'},
#    {'time': '[00:02:26]',
#     'speaker': 'Participant',
#     'text': 'Picking up artifacts feels satisfying. However, I expected some haptic feedback when I grabbed something, maybe a small vibration.'},
#    {'time': '[00:03:00]',
#     'speaker': 'Interviewer',
#     'text': 'Any technical or comfort issues?'},
#    {'time': '[00:03:33]',
#     'speaker': 'Participant',
#     'text': 'No lag, though the ambient sound loop is a little short—I noticed repetition after a few minutes.'},
#    {'time': '[00:04:00]',
#     'speaker': 'Interviewer',
#     'text': 'How would you rate the overall ease of use?'},
#    {'time': '[00:04:35]',
#     'speaker': 'Participant',
#     'text': 'Pretty intuitive overall. I’d just tweak interaction cues and maybe add a tutorial overlay at first launch.'}]},
#  {'id': 'P14',
#   'bio': '19-year-old Music Technology student named Emerson, male, highly familiar with VR and technology.',
#   'transcript': [{'time': '[00:00:05]',
#     'speaker': 'Interviewer',
#     'text': 'You are now in the HeritageRoots virtual lobby. What do you notice first?'},
#    {'time': '[00:00:10]',
#     'speaker': 'Participant',
#     'text': 'The lighting and spatial sound immediately make it feel immersive. I noticed the floating panels, but wasn’t sure which gesture activates them.'},
#    {'time': '[00:00:26]',
#     'speaker': 'Interviewer',
#     'text': 'Try navigating to a new scene using the teleport tool.'},
#    {'time': '[00:01:00]',
#     'speaker': 'Participant',
#     'text': 'Teleportation is smooth, but I’d like a quick preview of where I’ll land. The fade helps, but maybe a clearer arrow would help directionally.'},
#    {'time': '[00:01:08]',
#     'speaker': 'Interviewer',
#     'text': 'How do the menus and icons feel to interact with?'},
#    {'time': '[00:01:41]',
#     'speaker': 'Participant',
#     'text': 'The icons are intuitive but slightly small. I prefer when menus curve around my view instead of staying flat in front of me.'},
#    {'time': '[00:02:09]',
#     'speaker': 'Interviewer',
#     'text': 'Can you describe how object interaction feels?'},
#    {'time': '[00:02:43]',
#     'speaker': 'Participant',
#     'text': 'Picking up artifacts feels satisfying. However, I expected some haptic feedback when I grabbed something, maybe a small vibration.'},
#    {'time': '[00:03:05]',
#     'speaker': 'Interviewer',
#     'text': 'Any technical or comfort issues?'},
#    {'time': '[00:03:20]',
#     'speaker': 'Participant',
#     'text': 'No lag, though the ambient sound loop is a little short—I noticed repetition after a few minutes.'},
#    {'time': '[00:03:52]',
#     'speaker': 'Interviewer',
#     'text': 'How would you rate the overall ease of use?'},
#    {'time': '[00:04:02]',
#     'speaker': 'Participant',
#     'text': 'Pretty intuitive overall. I’d just tweak interaction cues and maybe add a tutorial overlay at first launch.'}]},
#  {'id': 'P15',
#   'bio': '26-year-old Communication student named Dakota, nonbinary, highly familiar with VR and technology.',
#   'transcript': [{'time': '[00:00:35]',
#     'speaker': 'Interviewer',
#     'text': 'You are now in the HeritageRoots virtual lobby. What do you notice first?'},
#    {'time': '[00:00:44]',
#     'speaker': 'Participant',
#     'text': 'The lighting and spatial sound immediately make it feel immersive. I noticed the floating panels, but wasn’t sure which gesture activates them.'},
#    {'time': '[00:01:03]',
#     'speaker': 'Interviewer',
#     'text': 'Try navigating to a new scene using the teleport tool.'},
#    {'time': '[00:01:29]',
#     'speaker': 'Participant',
#     'text': 'Teleportation is smooth, but I’d like a quick preview of where I’ll land. The fade helps, but maybe a clearer arrow would help directionally.'},
#    {'time': '[00:01:58]',
#     'speaker': 'Interviewer',
#     'text': 'How do the menus and icons feel to interact with?'},
#    {'time': '[00:02:11]',
#     'speaker': 'Participant',
#     'text': 'The icons are intuitive but slightly small. I prefer when menus curve around my view instead of staying flat in front of me.'},
#    {'time': '[00:02:29]',
#     'speaker': 'Interviewer',
#     'text': 'Can you describe how object interaction feels?'},
#    {'time': '[00:03:03]',
#     'speaker': 'Participant',
#     'text': 'Picking up artifacts feels satisfying. However, I expected some haptic feedback when I grabbed something, maybe a small vibration.'},
#    {'time': '[00:03:23]',
#     'speaker': 'Interviewer',
#     'text': 'Any technical or comfort issues?'},
#    {'time': '[00:03:44]',
#     'speaker': 'Participant',
#     'text': 'No lag, though the ambient sound loop is a little short—I noticed repetition after a few minutes.'},
#    {'time': '[00:04:11]',
#     'speaker': 'Interviewer',
#     'text': 'How would you rate the overall ease of use?'},
#    {'time': '[00:04:17]',
#     'speaker': 'Participant',
#     'text': 'Pretty intuitive overall. I’d just tweak interaction cues and maybe add a tutorial overlay at first launch.'}]},
#  {'id': 'P16',
#   'bio': '24-year-old Political Science student named Parker, male, highly familiar with VR and technology.',
#   'transcript': [{'time': '[00:00:18]',
#     'speaker': 'Interviewer',
#     'text': 'You are now in the HeritageRoots virtual lobby. What do you notice first?'},
#    {'time': '[00:00:46]',
#     'speaker': 'Participant',
#     'text': 'The lighting and spatial sound immediately make it feel immersive. I noticed the floating panels, but wasn’t sure which gesture activates them.'},
#    {'time': '[00:01:16]',
#     'speaker': 'Interviewer',
#     'text': 'Try navigating to a new scene using the teleport tool.'},
#    {'time': '[00:01:25]',
#     'speaker': 'Participant',
#     'text': 'Teleportation is smooth, but I’d like a quick preview of where I’ll land. The fade helps, but maybe a clearer arrow would help directionally.'},
#    {'time': '[00:01:30]',
#     'speaker': 'Interviewer',
#     'text': 'How do the menus and icons feel to interact with?'},
#    {'time': '[00:01:38]',
#     'speaker': 'Participant',
#     'text': 'The icons are intuitive but slightly small. I prefer when menus curve around my view instead of staying flat in front of me.'},
#    {'time': '[00:02:12]',
#     'speaker': 'Interviewer',
#     'text': 'Can you describe how object interaction feels?'},
#    {'time': '[00:02:42]',
#     'speaker': 'Participant',
#     'text': 'Picking up artifacts feels satisfying. However, I expected some haptic feedback when I grabbed something, maybe a small vibration.'},
#    {'time': '[00:03:12]',
#     'speaker': 'Interviewer',
#     'text': 'Any technical or comfort issues?'},
#    {'time': '[00:03:18]',
#     'speaker': 'Participant',
#     'text': 'No lag, though the ambient sound loop is a little short—I noticed repetition after a few minutes.'},
#    {'time': '[00:03:33]',
#     'speaker': 'Interviewer',
#     'text': 'How would you rate the overall ease of use?'},
#    {'time': '[00:03:59]',
#     'speaker': 'Participant',
#     'text': 'Pretty intuitive overall. I’d just tweak interaction cues and maybe add a tutorial overlay at first launch.'}]},
#  {'id': 'P17',
#   'bio': '26-year-old Geography student named Kai, nonbinary, highly familiar with VR and technology.',
#   'transcript': [{'time': '[00:00:22]',
#     'speaker': 'Interviewer',
#     'text': 'You are now in the HeritageRoots virtual lobby. What do you notice first?'},
#    {'time': '[00:00:27]',
#     'speaker': 'Participant',
#     'text': 'The lighting and spatial sound immediately make it feel immersive. I noticed the floating panels, but wasn’t sure which gesture activates them.'},
#    {'time': '[00:00:38]',
#     'speaker': 'Interviewer',
#     'text': 'Try navigating to a new scene using the teleport tool.'},
#    {'time': '[00:00:44]',
#     'speaker': 'Participant',
#     'text': 'Teleportation is smooth, but I’d like a quick preview of where I’ll land. The fade helps, but maybe a clearer arrow would help directionally.'},
#    {'time': '[00:01:10]',
#     'speaker': 'Interviewer',
#     'text': 'How do the menus and icons feel to interact with?'},
#    {'time': '[00:01:16]',
#     'speaker': 'Participant',
#     'text': 'The icons are intuitive but slightly small. I prefer when menus curve around my view instead of staying flat in front of me.'},
#    {'time': '[00:01:44]',
#     'speaker': 'Interviewer',
#     'text': 'Can you describe how object interaction feels?'},
#    {'time': '[00:02:13]',
#     'speaker': 'Participant',
#     'text': 'Picking up artifacts feels satisfying. However, I expected some haptic feedback when I grabbed something, maybe a small vibration.'},
#    {'time': '[00:02:27]',
#     'speaker': 'Interviewer',
#     'text': 'Any technical or comfort issues?'},
#    {'time': '[00:02:33]',
#     'speaker': 'Participant',
#     'text': 'No lag, though the ambient sound loop is a little short—I noticed repetition after a few minutes.'},
#    {'time': '[00:02:41]',
#     'speaker': 'Interviewer',
#     'text': 'How would you rate the overall ease of use?'},
#    {'time': '[00:03:03]',
#     'speaker': 'Participant',
#     'text': 'Pretty intuitive overall. I’d just tweak interaction cues and maybe add a tutorial overlay at first launch.'}]},
#  {'id': 'P18',
#   'bio': '27-year-old Neuroscience student named Elliot, male, highly familiar with VR and technology.',
#   'transcript': [{'time': '[00:00:10]',
#     'speaker': 'Interviewer',
#     'text': 'You are now in the HeritageRoots virtual lobby. What do you notice first?'},
#    {'time': '[00:00:43]',
#     'speaker': 'Participant',
#     'text': 'The lighting and spatial sound immediately make it feel immersive. I noticed the floating panels, but wasn’t sure which gesture activates them.'},
#    {'time': '[00:00:54]',
#     'speaker': 'Interviewer',
#     'text': 'Try navigating to a new scene using the teleport tool.'},
#    {'time': '[00:01:16]',
#     'speaker': 'Participant',
#     'text': 'Teleportation is smooth, but I’d like a quick preview of where I’ll land. The fade helps, but maybe a clearer arrow would help directionally.'},
#    {'time': '[00:01:23]',
#     'speaker': 'Interviewer',
#     'text': 'How do the menus and icons feel to interact with?'},
#    {'time': '[00:01:56]',
#     'speaker': 'Participant',
#     'text': 'The icons are intuitive but slightly small. I prefer when menus curve around my view instead of staying flat in front of me.'},
#    {'time': '[00:02:07]',
#     'speaker': 'Interviewer',
#     'text': 'Can you describe how object interaction feels?'},
#    {'time': '[00:02:29]',
#     'speaker': 'Participant',
#     'text': 'Picking up artifacts feels satisfying. However, I expected some haptic feedback when I grabbed something, maybe a small vibration.'},
#    {'time': '[00:02:36]',
#     'speaker': 'Interviewer',
#     'text': 'Any technical or comfort issues?'},
#    {'time': '[00:03:09]',
#     'speaker': 'Participant',
#     'text': 'No lag, though the ambient sound loop is a little short—I noticed repetition after a few minutes.'},
#    {'time': '[00:03:15]',
#     'speaker': 'Interviewer',
#     'text': 'How would you rate the overall ease of use?'},
#    {'time': '[00:03:40]',
#     'speaker': 'Participant',
#     'text': 'Pretty intuitive overall. I’d just tweak interaction cues and maybe add a tutorial overlay at first launch.'}]},
#  {'id': 'P19',
#   'bio': '28-year-old Art History student named Finley, female, highly familiar with VR and technology.',
#   'transcript': [{'time': '[00:00:15]',
#     'speaker': 'Interviewer',
#     'text': 'You are now in the HeritageRoots virtual lobby. What do you notice first?'},
#    {'time': '[00:00:22]',
#     'speaker': 'Participant',
#     'text': 'The lighting and spatial sound immediately make it feel immersive. I noticed the floating panels, but wasn’t sure which gesture activates them.'},
#    {'time': '[00:00:55]',
#     'speaker': 'Interviewer',
#     'text': 'Try navigating to a new scene using the teleport tool.'},
#    {'time': '[00:01:16]',
#     'speaker': 'Participant',
#     'text': 'Teleportation is smooth, but I’d like a quick preview of where I’ll land. The fade helps, but maybe a clearer arrow would help directionally.'},
#    {'time': '[00:01:31]',
#     'speaker': 'Interviewer',
#     'text': 'How do the menus and icons feel to interact with?'},
#    {'time': '[00:01:58]',
#     'speaker': 'Participant',
#     'text': 'The icons are intuitive but slightly small. I prefer when menus curve around my view instead of staying flat in front of me.'},
#    {'time': '[00:02:12]',
#     'speaker': 'Interviewer',
#     'text': 'Can you describe how object interaction feels?'},
#    {'time': '[00:02:30]',
#     'speaker': 'Participant',
#     'text': 'Picking up artifacts feels satisfying. However, I expected some haptic feedback when I grabbed something, maybe a small vibration.'},
#    {'time': '[00:02:49]',
#     'speaker': 'Interviewer',
#     'text': 'Any technical or comfort issues?'},
#    {'time': '[00:03:06]',
#     'speaker': 'Participant',
#     'text': 'No lag, though the ambient sound loop is a little short—I noticed repetition after a few minutes.'},
#    {'time': '[00:03:30]',
#     'speaker': 'Interviewer',
#     'text': 'How would you rate the overall ease of use?'},
#    {'time': '[00:03:36]',
#     'speaker': 'Participant',
#     'text': 'Pretty intuitive overall. I’d just tweak interaction cues and maybe add a tutorial overlay at first launch.'}]},
#  {'id': 'P20',
#   'bio': '29-year-old Economics student named Blake, male, highly familiar with VR and technology.',
#   'transcript': [{'time': '[00:00:33]',
#     'speaker': 'Interviewer',
#     'text': 'You are now in the HeritageRoots virtual lobby. What do you notice first?'},
#    {'time': '[00:00:44]',
#     'speaker': 'Participant',
#     'text': 'The lighting and spatial sound immediately make it feel immersive. I noticed the floating panels, but wasn’t sure which gesture activates them.'},
#    {'time': '[00:01:04]',
#     'speaker': 'Interviewer',
#     'text': 'Try navigating to a new scene using the teleport tool.'},
#    {'time': '[00:01:29]',
#     'speaker': 'Participant',
#     'text': 'Teleportation is smooth, but I’d like a quick preview of where I’ll land. The fade helps, but maybe a clearer arrow would help directionally.'},
#    {'time': '[00:01:51]',
#     'speaker': 'Interviewer',
#     'text': 'How do the menus and icons feel to interact with?'},
#    {'time': '[00:02:17]',
#     'speaker': 'Participant',
#     'text': 'The icons are intuitive but slightly small. I prefer when menus curve around my view instead of staying flat in front of me.'},
#    {'time': '[00:02:47]',
#     'speaker': 'Interviewer',
#     'text': 'Can you describe how object interaction feels?'},
#    {'time': '[00:03:13]',
#     'speaker': 'Participant',
#     'text': 'Picking up artifacts feels satisfying. However, I expected some haptic feedback when I grabbed something, maybe a small vibration.'},
#    {'time': '[00:03:29]',
#     'speaker': 'Interviewer',
#     'text': 'Any technical or comfort issues?'},
#    {'time': '[00:03:39]',
#     'speaker': 'Participant',
#     'text': 'No lag, though the ambient sound loop is a little short—I noticed repetition after a few minutes.'},
#    {'time': '[00:03:44]',
#     'speaker': 'Interviewer',
#     'text': 'How would you rate the overall ease of use?'},
#    {'time': '[00:03:49]',
#     'speaker': 'Participant',
#     'text': 'Pretty intuitive overall. I’d just tweak interaction cues and maybe add a tutorial overlay at first launch.'}]}]

# %%
# ---------- Flatten to a row-per-utterance dataframe ----------
rows: List[Dict] = []
for p in participants:
    pid = p.get("id")
    bio = p.get("bio")
    for turn in p.get("transcript", []):
        if turn.get("speaker") != "Participant":
            continue  # analyze only participant utterances
        rows.append({
            "participant_id": pid,
            "bio": bio,
            "time": turn.get("time"),
            "text": turn.get("text", "").strip()
        })

df = pd.DataFrame(rows)
print(f"Utterances (Participant): {len(df)}")
# Out:
# Utterances (Participant): 120

# %%
df.head()
# Out:
#   participant_id                                                bio  \
# 0            P01  24-year-old Computer Science student named Ale...
# 1            P01  24-year-old Computer Science student named Ale...
# 2            P01  24-year-old Computer Science student named Ale...
# 3            P01  24-year-old Computer Science student named Ale...
# 4            P01  24-year-old Computer Science student named Ale...
#
#          time                                               text
# 0  [00:00:48]  The lighting and spatial sound immediately mak...
# 1  [00:01:20]  Teleportation is smooth, but I’d like a quick ...
# 2  [00:01:54]  The icons are intuitive but slightly small. I ...
# 3  [00:02:16]  Picking up artifacts feels satisfying. However...
# 4  [00:03:08]  No lag, though the ambient sound loop is a lit...

# %%
# Optional: drop empty lines if any
df = df[df["text"].str.len() > 0].copy()

# %%
# ---------- Score sentiment per utterance ----------
def label_from_compound(score: float, pos=0.05, neg=-0.05) -> str:
    """Map VADER compound score to label: positive / neutral / negative."""
    if score >= pos:
        return "positive"
    elif score <= neg:
        return "negative"
    else:
        return "neutral"

scores = df["text"].apply(sia.polarity_scores).apply(pd.Series)
df = pd.concat([df, scores], axis=1)
df["label"] = df["compound"].apply(label_from_compound)

# %%
df.sample(5)
# Out:
#    participant_id                                                bio  \
# 79            P14  19-year-old Music Technology student named Eme...
# 57            P10  27-year-old Psychology student named Skyler, f...
# 37            P07  27-year-old History student named Morgan, nonb...
# 2             P01  24-year-old Computer Science student named Ale...
# 29            P05  28-year-old Information Science student named ...
#
#           time                                               text  neg    neu  \
# 79  [00:01:00]  Teleportation is smooth, but I’d like a quick ...  0.0  0.651
# 57  [00:02:43]  Picking up artifacts feels satisfying. However...  0.0  0.833
# 37  [00:00:46]  Teleportation is smooth, but I’d like a quick ...  0.0  0.651
# 2   [00:01:54]  The icons are intuitive but slightly small. I ...  0.0  1.000
# 29  [00:03:06]  Pretty intuitive overall. I’d just tweak inter...  0.0  0.824
#
#       pos  compound     label
# 79  0.349    0.8807  positive
# 57  0.167    0.4588  positive
# 37  0.349    0.8807  positive
# 2   0.000    0.0000   neutral
# 29  0.176    0.4939  positive

# %%
# Top clearly positive/negative quotes (by compound)
top_pos = df.sort_values("compound", ascending=False).head(1)
top_neg = df.sort_values("compound", ascending=True).head(1)

print("\nTop positive utterance:")
for _, r in top_pos.iterrows():
    print(f"- {r['participant_id']} {r['time']} | {r['compound']:.3f} | {r['text']}")

print("\nTop negative utterance:")
for _, r in top_neg.iterrows():
    print(f"- {r['participant_id']} {r['time']} | {r['compound']:.3f} | {r['text']}")
# Out:
# Top 5 positive utterances:
# - P12 [00:01:40] | 0.881 | Teleportation is smooth, but I’d like a quick preview of where I’ll land. The fade helps, but maybe a clearer arrow would help directionally.
# - P03 [00:01:21] | 0.881 | Teleportation is smooth, but I’d like a quick preview of where I’ll land. The fade helps, but maybe a clearer arrow would help directionally.
# - P17 [00:00:44] | 0.881 | Teleportation is smooth, but I’d like a quick preview of where I’ll land. The fade helps, but maybe a clearer arrow would help directionally.
# - P16 [00:01:25] | 0.881 | Teleportation is smooth, but I’d like a quick preview of where I’ll land. The fade helps, but maybe a clearer arrow would help directionally.
# - P07 [00:00:46] | 0.881 | Teleportation is smooth, but I’d like a quick preview of where I’ll land. The fade helps, but maybe a clearer arrow would help directionally.
#
# Top 5 negative utterances:
# - P07 [00:02:52] | -0.557 | No lag, though the ambient sound loop is a little short—I noticed repetition after a few minutes.
# - P04 [00:04:12] | -0.557 | No lag, though the ambient sound loop is a little short—I noticed repetition after a few minutes.
# - P16 [00:03:18] | -0.557 | No lag, though the ambient sound loop is a little short—I noticed repetition after a few minutes.
# - P05 [00:02:42] | -0.557 | No lag, though the ambient sound loop is a little short—I noticed repetition after a few minutes.
# - P18 [00:03:09] | -0.557 | No lag, though the ambient sound loop is a little short—I noticed repetition after a few minutes.

# %%
# ---------- Aggregate per participant ----------
agg = (
    df.groupby("participant_id")
      .agg(
          n_utterances=("text", "count"),
          compound_mean=("compound", "mean"),
          compound_median=("compound", "median"),
          pos_mean=("pos", "mean"),
          neg_mean=("neg", "mean"),
          neu_mean=("neu", "mean"),
      )
      .reset_index()
      .sort_values("compound_mean", ascending=False)
)

# Add a participant-level label from the mean compound
agg["participant_label"] = agg["compound_mean"].apply(label_from_compound)

# Join back one bio per participant
bios = df.groupby("participant_id")["bio"].first().reset_index()
agg = agg.merge(bios, on="participant_id", how="left")

print("\nParticipant-level sentiment summary:")
print(agg.head(10))

# ---------- Save outputs ----------
utterance_csv = OUT_DIR / "utterance_sentiment.csv"
participant_csv = OUT_DIR / "participant_sentiment_summary.csv"

df.to_csv(utterance_csv, index=False)
agg.to_csv(participant_csv, index=False)

print(f"\nSaved utterance-level sentiment to: {utterance_csv.resolve()}")
print(f"Saved participant-level summary to: {participant_csv.resolve()}")
# Out:
# Sample scored rows:
#    participant_id        time  \
# 44            P08  [00:01:59]
# 47            P08  [00:03:54]
# 4             P01  [00:03:08]
# 55            P10  [00:01:08]
# 26            P05  [00:01:54]
#
#                                                  text    neg    neu    pos  \
# 44  The icons are intuitive but slightly small. I ...  0.000  1.000  0.000
# 47  Pretty intuitive overall. I’d just tweak inter...  0.000  0.824  0.176
# 4   No lag, though the ambient sound loop is a lit...  0.261  0.739  0.000
# 55  Teleportation is smooth, but I’d like a quick ...  0.000  0.651  0.349
# 26  The icons are intuitive but slightly small. I ...  0.000  1.000  0.000
#
#     compound     label
# 44    0.0000   neutral
# 47    0.4939  positive
# 4    -0.5574  negative
# 55    0.8807  positive
# 26    0.0000   neutral
#
# Top 5 positive utterances:
# - P12 [00:01:40] | 0.881 | Teleportation is smooth, but I’d like a quick preview of where I’ll land. The fade helps, but maybe a clearer arrow would help directionally.
# - P03 [00:01:21] | 0.881 | Teleportation is smooth, but I’d like a quick preview of where I’ll land. The fade helps, but maybe a clearer arrow would help directionally.
# - P17 [00:00:44] | 0.881 | Teleportation is smooth, but I’d like a quick preview of where I’ll land. The fade helps, but maybe a clearer arrow would help directionally.
# - P16 [00:01:25] | 0.881 | Teleportation is smooth, but I’d like a quick preview of where I’ll land. The fade helps, but maybe a clearer arrow would help directionally.
# - P07 [00:00:46] | 0.881 | Teleportation is smooth, but I’d like a quick preview of where I’ll land. The fade helps, but maybe a clearer arrow would help directionally.
#
# Top 5 negative utterances:
# - P07 [00:02:52] | -0.557 | No lag, though the ambient sound loop is a little short—I noticed repetition after a few minutes.
# - P04 [00:04:12] | -0.557 | No lag, though the ambient sound loop is a little short—I noticed repetition after a few minutes.
# - P16 [00:03:18] | -0.557 | No lag, though the ambient sound loop is a little short—I noticed repetition after a few minutes.
# - P05 [00:02:42] | -0.557 | No lag, though the ambient sound loop is a little short—I noticed repetition after a few minutes.
# - P18 [00:03:09] | -0.557 | No lag, though the ambient sound loop is a little short—I noticed repetition after a few minutes.
#
# Participant-level sentiment summary:
#   participant_id  n_utterances  compound_mean  compound_median  pos_mean  \
# 0            P01             6       0.287617          0.45425  0.136833
# 1            P02             6       0.287617          0.45425  0.136833
# 2            P19             6       0.287617          0.45425  0.136833
# 3            P18             6       0.287617          0.45425  0.136833
# 4            P17             6       0.287617          0.45425  0.136833
# 5            P16             6       0.287617          0.45425  0.136833
# 6            P15             6       0.287617          0.45425  0.136833
# 7            P14             6       0.287617          0.45425  0.136833
# 8            P13             6       0.287617          0.45425  0.136833
# 9            P12             6       0.287617          0.45425  0.136833
#
#    neg_mean  neu_mean participant_label  \
# 0    0.0435  0.819667          positive
# 1    0.0435  0.819667          positive
# 2    0.0435  0.819667          positive
# 3    0.0435  0.819667          positive
# 4    0.0435  0.819667          positive
# 5    0.0435  0.819667          positive
# 6    0.0435  0.819667          positive
# 7    0.0435  0.819667          positive
# 8    0.0435  0.819667          positive
# 9    0.0435  0.819667          positive
#
#                                                  bio
# 0  24-year-old Computer Science student named Ale...
# 1  22-year-old Anthropology student named Jamie, ...
# 2  28-year-old Art History student named Finley, ...
# 3  27-year-old Neuroscience student named Elliot,...
# 4  26-year-old Geography student named Kai, nonbi...
# 5  24-year-old Political Science student named Pa...
# 6  26-year-old Communication student named Dakota...
# 7  19-year-old Music Technology student named Eme...
# 8  21-year-old Education student named Reese, non...
# 9  26-year-old Digital Humanities student named Q...
#
# Saved utterance-level sentiment to: /Users/dmitriyb/Desktop/Class Examples/ux_engineering/qualitative_data_analysis/data/sentiment_outputs/utterance_sentiment.csv
# Saved participant-level summary to: /Users/dmitriyb/Desktop/Class Examples/ux_engineering/qualitative_data_analysis/data/sentiment_outputs/participant_sentiment_summary.csv
